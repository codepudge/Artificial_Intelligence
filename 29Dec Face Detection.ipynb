# %%
#Steps to be followed

#1. Read an Image
#2. Call for Cascade classifier from OpenCV
#3. Call Get Multiscale function
#4. Plot the rectangle

# %%
# !wget https://www.quickanddirtytips.com/sites/default/files/styles/convert_webp_article_main_image/public/images/2332/people-persons-peoples.jpg -O p1.jpg
# Out:
# --2021-12-29 12:19:38--  https://www.quickanddirtytips.com/sites/default/files/styles/convert_webp_article_main_image/public/images/2332/people-persons-peoples.jpg
# Resolving www.quickanddirtytips.com (www.quickanddirtytips.com)... 52.200.132.133
# Connecting to www.quickanddirtytips.com (www.quickanddirtytips.com)|52.200.132.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53802 (53K) [image/webp]
# Saving to: ‘p1.jpg’
#
# p1.jpg              100%[===================>]  52.54K  --.-KB/s    in 0.06s
#
# 2021-12-29 12:19:38 (826 KB/s) - ‘p1.jpg’ saved [53802/53802]

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread("/content/p1.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=710x533 at 0x7FFA3E815FD0>

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Out:
# --2021-12-29 12:28:16--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal 100%[===================>] 908.33K  --.-KB/s    in 0.03s
#
# 2021-12-29 12:28:16 (26.3 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [930127/930127]

# %%
img = cv2.imread("/content/p1.jpg")
model=cv2.CascadeClassifier("/content/haarcascade_frontalface_default.xml")
face=model.detectMultiScale(img,1.2,2)
for (x,y,w,h) in face:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=710x533 at 0x7FFA3CC63210>

# %%
face
# Out:
# array([[391,  44, 141, 141],
#        [258,  60, 150, 150],
#        [ 51, 180, 176, 176],
#        [188, 205, 142, 142],
#        [278, 326, 178, 178],
#        [425, 309, 214, 214]], dtype=int32)

# %%
# !wget https://imagesvc.meredithcorp.io/v3/mm/image?url=https%3A%2F%2Fstatic.onecms.io%2Fwp-content%2Fuploads%2Fsites%2F20%2F2021%2F03%2F25%2Ftout-peopletv.jpg -O p2.jpg
# Out:
# --2021-12-29 12:44:19--  https://imagesvc.meredithcorp.io/v3/mm/image?url=https%3A%2F%2Fstatic.onecms.io%2Fwp-content%2Fuploads%2Fsites%2F20%2F2021%2F03%2F25%2Ftout-peopletv.jpg
# Resolving imagesvc.meredithcorp.io (imagesvc.meredithcorp.io)... 13.224.7.6, 13.224.7.9, 13.224.7.48, ...
# Connecting to imagesvc.meredithcorp.io (imagesvc.meredithcorp.io)|13.224.7.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 386639 (378K) [image/jpeg]
# Saving to: ‘p2.jpg’
#
# p2.jpg              100%[===================>] 377.58K  --.-KB/s    in 0.03s
#
# 2021-12-29 12:44:19 (13.2 MB/s) - ‘p2.jpg’ saved [386639/386639]

# %%
img1 = cv2.imread("/content/p2.jpg")
model=cv2.CascadeClassifier("/content/haarcascade_frontalface_default.xml")
face=model.detectMultiScale(img1,1.2,10)
for (x,y,w,h) in face:
  cv2.rectangle(img1,(x,y),(x+w,y+h),(0,255,255),2)
cv2_imshow(img1)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml
# Out:
# --2021-12-29 12:51:32--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 341406 (333K) [text/plain]
# Saving to: ‘haarcascade_eye.xml’
#
# haarcascade_eye.xml 100%[===================>] 333.40K  --.-KB/s    in 0.02s
#
# 2021-12-29 12:51:32 (13.5 MB/s) - ‘haarcascade_eye.xml’ saved [341406/341406]

# %%
img=cv2.imread("p1.jpg")
model1=cv2.CascadeClassifier("/content/haarcascade_eye.xml")
eye= model1.detectMultiScale(img,1.2,6)
for (x,y,w,h) in eye:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=710x533 at 0x7FFA3CC5E1D0>

# %%
img1=cv2.imread("p2.jpg")
model1=cv2.CascadeClassifier("/content/haarcascade_eye.xml")
eye= model1.detectMultiScale(img1,1.2,6)
for (x,y,w,h) in eye:
  cv2.rectangle(img1,(x,y),(x+w,y+h),(0,255,255),6)
cv2_imshow(img1)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
img = cv2.imread("/content/p1.jpg")
model=cv2.CascadeClassifier("/content/haarcascade_frontalface_default.xml")
face=model.detectMultiScale(img,1.2,2)
for (x,y,w,h) in face:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)
model1=cv2.CascadeClassifier("/content/haarcascade_eye.xml")
eye= model1.detectMultiScale(img,1.2,6)
for (x,y,w,h) in eye:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=710x533 at 0x7FFA3E772610>

# %%
img1=cv2.imread("p2.jpg")
model=cv2.CascadeClassifier("/content/haarcascade_frontalface_default.xml")
face=model.detectMultiScale(img1,1.2,10)
for (x,y,w,h) in face:
  cv2.rectangle(img1,(x,y),(x+w,y+h),(0,255,0),2)
model1=cv2.CascadeClassifier("/content/haarcascade_eye.xml")
eye= model1.detectMultiScale(img1,1.2,6)
for (x,y,w,h) in eye:
  cv2.rectangle(img1,(x,y),(x+w,y+h),(0,255,255),6)
cv2_imshow(img1)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
