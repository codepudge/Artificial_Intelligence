# %%
# !git clone https://github.com/ultralytics/yolov5 #clone the repository
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10344, done.
# remote: Total 10344 (delta 0), reused 0 (delta 0), pack-reused 10344
# Receiving objects: 100% (10344/10344), 10.59 MiB | 14.41 MiB/s, done.
# Resolving deltas: 100% (7143/7143), done.

# %%
# %cd yolov5
# %pip install -qr requirements.txt  #install all the dependency libraries

import torch
from IPython.display import Image, clear_output #to display images
clear_output()
print("Setup is complete. Using torch ", torch.__version__)
# Out:
# Setup is complete. Using torch  1.10.0+cu111

# %%
#RUNTIME :>  Change runtime type >- Hardware accelerator >-GPU

# %%
pwd
# Out:
# '/content/yolov5'

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# Out:
# ...
# detect: weights=['yolov5s.pt'], source=data/images, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...
# 100% 14.0M/14.0M [00:00<00:00, 21.3MB/s]
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, Done. (0.032s)
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 1 tie, Done. (0.029s)
# Speed: 0.5ms pre-process, 30.6ms inference, 18.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
Image(filename="runs/detect/exp/zidane.jpg",width=600)

# %%
Image(filename="runs/detect/exp/bus.jpg",width=600)

# %%
# !wget 'https://media.gettyimages.com/photos/crowds-of-people-crossing-street-on-zebra-crossing-in-new-york-usa-picture-id1161240357' -O 123.jpg
# Out:
# --2021-12-29 13:42:17--  https://media.gettyimages.com/photos/crowds-of-people-crossing-street-on-zebra-crossing-in-new-york-usa-picture-id1161240357
# Resolving media.gettyimages.com (media.gettyimages.com)... 13.35.33.119, 13.35.33.127, 13.35.33.87, ...
# Connecting to media.gettyimages.com (media.gettyimages.com)|13.35.33.119|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 494140 (483K) [image/jpeg]
# Saving to: ‘123.jpg’
#
# 123.jpg             100%[===================>] 482.56K  1.63MB/s    in 0.3s
#
# 2021-12-29 13:42:17 (1.63 MB/s) - ‘123.jpg’ saved [494140/494140]

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread("/content/yolov5/123.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x682 at 0x7FB861F39790>

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /content/pexels-anastasia-shuraeva-5705008 (2).mp4
# Out:
# detect: weights=['yolov5s.pt'], source=/content/yolov5/123.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/yolov5/123.jpg: 448x640 22 persons, 2 cars, 3 traffic lights, 1 umbrella, 1 handbag, 2 suitcases, Done. (0.030s)
# Speed: 0.6ms pre-process, 30.0ms inference, 1.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
Image(filename="/content/yolov5/runs/detect/exp2/123.jpg",width=600)
